# %% [markdown]
# # Python 주요 데이터분석 라이브러리
# 1) 넘파이(NumPy)
# 	- Python 데이터 분석의 기본적인 기능들을 제공
# 	- 특히 벡터 및 행렬 연산과 관련된 편리한 기능들을 제공
#
# 2) 판다스(Pandas)
# 	- Series, DataFrame 등의 자료 구조를 활용하여 데이터 분석에 있어 우수한 성능을 발휘함
# 	- 대량의 데이터를 더욱 빠른 속도로 처리할 수 있음
#
# 3) 맷플롯립(Matplotlib)
# 	- 데이터 분석 결과에 대한 시각화를 빠르고 직관적으로 수행

# %%
# %매직명령어
# 그래프 출력 과정을 볼 수 있도록 설정
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
# 50개의 난수 생성(0.0 ~ 1.0 사이의 값, 실행할 때마다 다른 값이 나옴)
data = np.random.rand(50)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.36127109 0.28413631 0.56312963 0.95269465 0.69175121 0.39689768
#  0.92822643 0.89079706 0.3785683  0.91388275 0.30521117 0.7932181
#  0.72577469 0.81247039 0.54156806 0.5130902  0.9346174  0.77405224
#  0.0924497  0.45489123 0.07252312 0.04928644 0.53190601 0.28984053
#  0.69447341 0.32344687 0.28784354 0.9193395  0.44360447 0.362276
#  0.28351412 0.35371806 0.96355386 0.90096913 0.34138349 0.04165657
#  0.61990658 0.76432815 0.6603335  0.78406884 0.3021886  0.63018359
#  0.74043911 0.37883926 0.03619289 0.15382483 0.21252535 0.33508501
#  0.41666386 0.3889287 ]

# %%
# 넘파이 배열을 판다스의 시리즈 자료형으로 변환(인덱스, 데이터의 조합)
seri = pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0     0.361271
# 1     0.284136
# 2     0.563130
# 3     0.952695
# 4     0.691751
# 5     0.396898
# 6     0.928226
# 7     0.890797
# 8     0.378568
# 9     0.913883
# 10    0.305211
# 11    0.793218
# 12    0.725775
# 13    0.812470
# 14    0.541568
# 15    0.513090
# 16    0.934617
# 17    0.774052
# 18    0.092450
# 19    0.454891
# 20    0.072523
# 21    0.049286
# 22    0.531906
# 23    0.289841
# 24    0.694473
# 25    0.323447
# 26    0.287844
# 27    0.919339
# 28    0.443604
# 29    0.362276
# 30    0.283514
# 31    0.353718
# 32    0.963554
# 33    0.900969
# 34    0.341383
# 35    0.041657
# 36    0.619907
# 37    0.764328
# 38    0.660334
# 39    0.784069
# 40    0.302189
# 41    0.630184
# 42    0.740439
# 43    0.378839
# 44    0.036193
# 45    0.153825
# 46    0.212525
# 47    0.335085
# 48    0.416664
# 49    0.388929
# dtype: float64

# %%
# x축 인덱스값, y축 랜덤값
seri.plot()

# %%
# 그래프 스타일 변경
matplotlib.style.use("ggplot")
# 그래프 출력
seri.plot()

# %%
# rand(rows, cols)
# 10행 3열의 행렬
data_set = np.random.rand(10, 3)
print(data_set)
print(type(data_set)) # 변수의 자료형 확인
print(data_set.shape) # 행렬의 차원 확인
# Out:
# [[0.16457994 0.03098103 0.73824437]
#  [0.05227865 0.71225888 0.50798185]
#  [0.31807313 0.97286353 0.64551252]
#  [0.53992502 0.80136154 0.52892707]
#  [0.69821614 0.28692386 0.03651884]
#  [0.82463462 0.06727892 0.47836115]
#  [0.27497176 0.32685082 0.83697098]
#  [0.06168142 0.96911044 0.89758023]
#  [0.73607332 0.77448883 0.66538367]
#  [0.57389831 0.4623184  0.34124798]]
# <class 'numpy.ndarray'>
# (10, 3)

# %%
# 넘파이 행렬을 판다스의 데이터프레임으로 변환
# 데이터프레임 : 행과 열로 데이터를 조회할 수 있음
df = pd.DataFrame(data_set, columns=["A", "B", "C"])
# df
print(df)
print(type(df))
# Out:
#           A         B         C
# 0  0.164580  0.030981  0.738244
# 1  0.052279  0.712259  0.507982
# 2  0.318073  0.972864  0.645513
# 3  0.539925  0.801362  0.528927
# 4  0.698216  0.286924  0.036519
# 5  0.824635  0.067279  0.478361
# 6  0.274972  0.326851  0.836971
# 7  0.061681  0.969110  0.897580
# 8  0.736073  0.774489  0.665384
# 9  0.573898  0.462318  0.341248
# <class 'pandas.core.frame.DataFrame'>

# %%
# 데이터프레임의 자료를 그래프로 출력
df.plot()

# %%
# 막대 그래프로 출력
df.plot(kind="bar")

# %%
# 수평 막대그래프로 출력
df.plot(kind="barh")

# %%
# 누적 그래프로 출력
df.plot(kind="area")

# %%
# 개별 면적 그래프
df.plot(kind="area", stacked=False)

# %%
# 넘파이의 랜덤값 5개 => 판다스의 시리즈 자료형으로 변환
seri2 = pd.Series(\
np.random.rand(5), index=["a", "b", "c", "d", "e"], name="series")
seri2.plot(kind="pie", autopct="%.2f", fontsize=20, figsize=(7,5))
